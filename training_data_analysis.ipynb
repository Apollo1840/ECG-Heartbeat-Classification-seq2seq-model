# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open("x_train_ds1ds2.pkl", "rb") as f:
    X_train = pickle.load(f)

with open("y_train_ds1ds2.pkl", "rb") as f:
    y_train = pickle.load(f)
    
with open("x_train_ds1ds2_oversample.pkl", "rb") as f:
    X_train_oversample = pickle.load(f)

with open("y_train_ds1ds2_oversample.pkl", "rb") as f:
    y_train_oversample = pickle.load(f)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_train_oversample.shape)
print(y_train_oversample.shape)
# Out:
# (5052, 10, 280)
# (5052, 11)
# (5879, 10, 280)
# (5879, 11)

# %%
plt.plot(X_train[0][0])
